# %% [markdown]
# # Database Setup

# %% [markdown]
# Data is originally from <br>
# https://github.com/binlist<br>
# https://github.com/iannuttall/binlist-data<br>
# and manually entering bins. This data has been combined and modified.

# %% [markdown]
# Imports

# %%
# Generic Import
import pandas as pd
from pymongo import MongoClient
import numpy as np
import json

db_cert = "ca-certificate.crt" #PATH/TO/ca-certificate.crt

# %% [markdown]
# Connect to/create MongoDB database

# %%
def get_database(db_name):
    # Load connection string from creds.json
    with open('creds.json') as creds:
        CONNECTION_STRING = json.load(creds)['MongoDB']['connection_string'] + db_cert

    # Create a connection using MongoClient
    client = MongoClient(CONNECTION_STRING)

    return client[db_name] # return database

# %%
db = get_database('bin_list')
bins = db['bins'] # create collection in db bin_list

# %% [markdown]
# # Enter Values manually into the databse

# %% [markdown]
# See all bins currently in database

# %%
for bin in bins.find({}):
    #bins.delete_one(bin)
    print(bin['Bin'])
# Out:
# 411810
# 409758
# 377935
# 545660
# 515557
# 403015
# 403446
# 414238
# 435880
# 484718
# 485246
# 494160
# 525362

# %% [markdown]
# Let's add BINS manually

# %%
response = input("Enter a BIN: ")
while response != "exit":
    if len(response) < 6:
        print("Please enter a 6 digit bin number.")
        response = input("Enter a BIN: ")
        continue
    if len([bin for bin in bins.find({'Bin': response})]) == 0:
        info = {'Bin': response}
        info['Type'] = input("Type of Card (Debit/Credit): ")
        info['Reloadable'] = input("Is the card Reloadable? (Y/N): ")
        info['Category'] = input("Category (Prepaid, Gift, Credit, Debit): ")
        info['Company'] = input("Company (Vanilla, MyVanilla, etc.): ")
        info['Distributor'] = input("Financial Distributor (InComm Financial Services): ")
        info['Issuer'] = input("Issuer (bank that issues): ")
        info['Website'] = input("Website (include https:// and trailing /): ")
        info['Customer Service'] = input('Support number (1-833-322-6760): ')
        info['Country'] = input("USA")
        print("Submitting: ")
        for k, v in info.items():
            print(f"{k}: {v}")
        bins.insert_one(info).inserted_id
        print("Saved")
        response = input("Enter a BIN: ")
    else:
        print("BIN Already Uploaded.")
        response = input("Enter a BIN: ")
print("Finished")
# Out:
# Finished

# %% [markdown]
# View number of bins in the database now

# %%
len([bin for bin in bins.find({})])
# Out:
# 338734

# %% [markdown]
# # Adding CSV's to the database

# %% [markdown]
# Let's clean up the first CSV and then upload to the database

# %%
bin1 = pd.read_csv('binlist-data.csv')
bin1
# Out:
#              bin          brand   type category      issuer alpha_2 alpha_3  \
# 0          19627  PRIVATE LABEL  DEBIT      NaN         NaN      US     USA
# 1          21502  PRIVATE LABEL  DEBIT      NaN         NaN      US     USA
# 2          42410  PRIVATE LABEL  DEBIT      NaN         NaN      US     USA
# 3          57164  PRIVATE LABEL  DEBIT      NaN         NaN      US     USA
# 4          63047           VISA  DEBIT      NaN         NaN      US     USA
# ...          ...            ...    ...      ...         ...     ...     ...
# 343058  45719896           VISA  DEBIT  DANKORT   SPAR NORD      DK     DNK
# 343059  45719897           VISA  DEBIT  DANKORT   SPAR NORD      DK     DNK
# 343060  45719898           VISA  DEBIT  DANKORT   SPAR NORD      DK     DNK
# 343061  45719899           VISA  DEBIT  DANKORT  BANKNORDIK      DK     DNK
# 343062  45719942           VISA  DEBIT  DANKORT   DIBA BANK      DK     DNK
#
#               country  latitude  longitude bank_phone bank_url
# 0       United States   37.0902  -95.71290        NaN      NaN
# 1       United States   37.0902  -95.71290        NaN      NaN
# 2       United States   37.0902  -95.71290        NaN      NaN
# 3       United States   37.0902  -95.71290        NaN      NaN
# 4       United States   37.0902  -95.71290        NaN      NaN
# ...               ...       ...        ...        ...      ...
# 343058        Denmark   56.2639    9.50179        NaN      NaN
# 343059        Denmark   56.2639    9.50179        NaN      NaN
# 343060        Denmark   56.2639    9.50179        NaN      NaN
# 343061        Denmark   56.2639    9.50179        NaN      NaN
# 343062        Denmark   56.2639    9.50179        NaN      NaN
#
# [343063 rows x 12 columns]

# %% [markdown]
# Let's drop unused columns from this CSV

# %%
# bin1 = bin1.drop(columns = ['alpha_2', 'country', 'latitude', 'longitude'])
bin1
# Out:
#              bin          brand   type category      issuer alpha_3  \
# 0          19627  PRIVATE LABEL  DEBIT      NaN         NaN     USA
# 1          21502  PRIVATE LABEL  DEBIT      NaN         NaN     USA
# 2          42410  PRIVATE LABEL  DEBIT      NaN         NaN     USA
# 3          57164  PRIVATE LABEL  DEBIT      NaN         NaN     USA
# 4          63047           VISA  DEBIT      NaN         NaN     USA
# ...          ...            ...    ...      ...         ...     ...
# 343058  45719896           VISA  DEBIT  DANKORT   SPAR NORD     DNK
# 343059  45719897           VISA  DEBIT  DANKORT   SPAR NORD     DNK
# 343060  45719898           VISA  DEBIT  DANKORT   SPAR NORD     DNK
# 343061  45719899           VISA  DEBIT  DANKORT  BANKNORDIK     DNK
# 343062  45719942           VISA  DEBIT  DANKORT   DIBA BANK     DNK
#
#        bank_phone bank_url
# 0             NaN      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4             NaN      NaN
# ...           ...      ...
# 343058        NaN      NaN
# 343059        NaN      NaN
# 343060        NaN      NaN
# 343061        NaN      NaN
# 343062        NaN      NaN
#
# [343063 rows x 8 columns]

# %% [markdown]
# Create a for loop to add this information to the DB (we do NOT want to overwrite current data)

# %%
def add_bin(bin_info):
    if len([bin for bin in bins.find({'Bin': bin_info['bin']})]) == 0:
        info = {'Bin': bin_info['bin']}
        info['Type'] = bin_info['type']
        info['Reloadable'] = ''
        info['Category'] = bin_info['type']
        info['Company'] = ''
        info['Distributor'] = ''
        info['Issuer'] = bin_info['issuer']
        info['Website'] = bin_info['bank_url']
        info['Customer Service'] = bin_info['bank_phone']
        info['Country'] = bin_info['alpha_3']
        bins.insert_one(info).inserted_id
    else:
        print("BIN Already Uploaded.")

# %%
bin1.apply(add_bin, axis = 1)

# %% [markdown]
# Now we must redo the process for the second CSV

# %%
bin2 = pd.read_csv('ranges.csv')
bin2
# Out:
#       iin_start  iin_end  number_length  number_luhn      scheme  \
# 0        341142      NaN            NaN          NaN        amex
# 1        342562      NaN            NaN          NaN        amex
# 2        360218      NaN            NaN          NaN      diners
# 3        360324      NaN            NaN          NaN      diners
# 4        361766      NaN            NaN          NaN      diners
# ...         ...      ...            ...          ...         ...
# 5800     622698      NaN            NaN          NaN    unionpay
# 5801     651621      NaN            NaN          NaN    discover
# 5802     655066      NaN            NaN          NaN    discover
# 5803     659524      NaN            NaN          NaN    discover
# 5804     670686      NaN            NaN          NaN  mastercard
#
#                           brand    type prepaid country  \
# 0                           NaN  credit     NaN      US
# 1                           NaN  credit     NaN      US
# 2     Diners Club International  credit     NaN      EC
# 3     Diners Club International  credit     NaN      CO
# 4                   Diners Club  credit     NaN      CZ
# ...                         ...     ...     ...     ...
# 5800                        NaN   debit     NaN      CN
# 5801                        NaN  credit     NaN      US
# 5802                        NaN  credit     NaN      US
# 5803                        NaN  credit     NaN      US
# 5804                    Maestro   debit     NaN      DE
#
#                          bank_name  bank_logo                 bank_url  \
# 0                 AMERICAN EXPRESS        NaN  www.americanexpress.com
# 1                 AMERICAN EXPRESS        NaN  www.americanexpress.com
# 2     DINERS CLUB DEL ECUADOR S.A.        NaN    www.dinersclub.com.ec
# 3            Banco Davivienda S.A.        NaN       www.davivienda.com
# 4     DINERS CLUB INTERNATIONAL CS        NaN        www.dinersclub.cz
# ...                            ...        ...                      ...
# 5800              CHINA CITIC BANK        NaN          bank.ecitic.com
# 5801                      DISCOVER        NaN                      NaN
# 5802                      DISCOVER        NaN                      NaN
# 5803                      DISCOVER        NaN                      NaN
# 5804                 Fidor Bank AG        NaN             www.fidor.de
#
#             bank_phone    bank_city
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2      +593 2 297 3100        Quito
# 3        +57 1 3383838  Bogota D.C.
# 4     +420 255 712 712       PRAGUE
# ...                ...          ...
# 5800         +86 95558          NaN
# 5801        8003472683          NaN
# 5802        8003472683          NaN
# 5803        8003472683          NaN
# 5804         +49116116      München
#
# [5805 rows x 14 columns]

# %%
bin2 = bin2.drop(columns = ['iin_end', 'number_length', 'number_luhn', 'scheme', 'bank_logo', 'bank_city'])
bin2.head(5)
# Out:
#    iin_start                      brand    type prepaid country  \
# 0     341142                        NaN  credit     NaN      US
# 1     342562                        NaN  credit     NaN      US
# 2     360218  Diners Club International  credit     NaN      EC
# 3     360324  Diners Club International  credit     NaN      CO
# 4     361766                Diners Club  credit     NaN      CZ
#
#                       bank_name                 bank_url        bank_phone
# 0              AMERICAN EXPRESS  www.americanexpress.com               NaN
# 1              AMERICAN EXPRESS  www.americanexpress.com               NaN
# 2  DINERS CLUB DEL ECUADOR S.A.    www.dinersclub.com.ec   +593 2 297 3100
# 3         Banco Davivienda S.A.       www.davivienda.com     +57 1 3383838
# 4  DINERS CLUB INTERNATIONAL CS        www.dinersclub.cz  +420 255 712 712

# %%
def add_bin2(bin_info):
    if len([bin for bin in bins.find({'Bin': bin_info['iin_start']})]) == 0:
        info = {'Bin': bin_info['iin_start']}
        info['Type'] = bin_info['brand']
        info['Reloadable'] = ''
        info['Category'] = bin_info['prepaid']
        info['Company'] = ''
        info['Distributor'] = ''
        info['Issuer'] = bin_info['bank_name']
        info['Website'] = bin_info['bank_url']
        info['Customer Service'] = bin_info['bank_phone']
        info['Country'] = bin_info['country']
        bins.insert_one(info).inserted_id
    else:
        print("BIN Already Uploaded.")

# %%
bin2.apply(add_bin2, axis = 1)

# %% [markdown]
# Change string bins to integers to be compatible with API

# %%
db = get_database('bin_list')
bins = db['bins'] # create collection in db bin_list
for bin in bins.find({'Bin': {'$type': 'string'}}):
    bins.update_one({'_id': bin['_id']}, {'$set': {'Bin': int(bin['Bin'])}})

# %% [markdown]
# Change NaN to empty strings

# %%
db = get_database('bin_list')
bins = db['bins'] # create collection in db bin_list
for column in ['Type', 'Reloadable', 'Category', 'Company', 'Distributor', 'Issuer', 'Website', 'Customer Service', 'Country']:
    for bin in bins.find({column: {'$eq': np.nan}}):
        bins.update_one({'_id': bin['_id']}, {'$set': {column: ''}})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jacoblloyd/Documents/BIN Checker/sql-setup.ipynb Cell 31' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000030?line=0'>1</a> db = get_database('bin_list')
#       <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000030?line=1'>2</a> bins = db['bins'] # create collection in db bin_list
#       <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000030?line=2'>3</a> for column in ['Type', 'Reloadable', 'Category', 'Company', 'Distributor', 'Issuer', 'Website', 'Customer Service', 'Country']:
#
# /Users/jacoblloyd/Documents/BIN Checker/sql-setup.ipynb Cell 6' in get_database(db_name)
#       <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000005?line=0'>1</a> def get_database(db_name):
#       <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000005?line=1'>2</a>     # Load connection string from creds.json
#       <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000005?line=2'>3</a>     with open('creds.json') as creds:
# ----> <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000005?line=3'>4</a>         CONNECTION_STRING = json.load(creds)['MongoDB']['connection_string'] + db_cert
#       <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000005?line=5'>6</a>     # Create a connection using MongoClient
#       <a href='vscode-notebook-cell:/Users/jacoblloyd/Documents/BIN%20Checker/sql-setup.ipynb#ch0000005?line=6'>7</a>     client = MongoClient(CONNECTION_STRING)
#
# NameError: name 'json' is not defined
